# %% [markdown]
# # Simple Linear Regression
#
# y' = bo + b1*x1
#
# What is to be predicted = y_intercept + slope coefficient * independant variable(feature)

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Salary_Data.csv')
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %%
print(X)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]

# %%
print(y)
# Out:
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## Training the Simple Linear Regression model on the Training set

# %%
from sklearn.linear_model import LinearRegression
#regression - predict real continuous values
regressor = LinearRegression()
#train the SLR model on the training set. It expects X_train and y_train
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predicting the Test set results

# %%
#predicted salaries vector
y_pred = regressor.predict(X_test)

# %% [markdown]
# ## Visualising the Training set results

# %%
#plot real salaries vs predicted salaries. X - no of years. Y - salaries. Red dots are real salaries and blue line is predicted salaries.
plt.scatter(X_train, y_train, color = "red")
#plot regression  line - line of prediction coming as close as possible to real salaries.
plt.plot(X_train,  regressor.predict(X_train), color = "blue")
plt.title("Salary vs Experience (Training set)")
plt.xlabel("Years of Experience")
plt.ylabel("Salaries")
plt.show()

# %% [markdown]
# ## Visualising the Test set results

# %%
#plot real salaries vs predicted salaries. X - no of years. Y - salaries. Red dots are real salaries and blue line is predicted salaries.
plt.scatter(X_test, y_test, color = "red")
#plot regression  line - line of prediction coming as close as possible to real salaries.
#We always get same regression line in training and test so even if we made no change to next line, it would still be same.
plt.plot(X_test, y_pred , color = "blue")
plt.title("Salary vs Experience (Test set)")
plt.xlabel("Years of Experience")
plt.ylabel("Salaries")
plt.show()

#We get such a beautiful line because our dataset had linear correlation. Non linear datasets would require non linear regression like polynomial, etc.

# %%
print(regressor.predict([[12]]))
# Out:
# [138531.00067138]

# %%
print(regressor.coef_)
print(regressor.intercept_)
# Out:
# [9312.57512673]
# 26780.09915062818

# %% [markdown]
# Salary = 26816.19 + 9345.94 × YearsExperience
